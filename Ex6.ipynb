# %% [markdown]
# <a href="https://colab.research.google.com/github/NSCC-ITC-Winter2024-DBAS5125-700-MCr/exercise-6-pdushie/blob/main/Ex6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 6 Notebook

# %% [markdown]
# ## Install ydata profiling library

# %%
# %pip install ydata-profiling

# %% [markdown]
# ## Import all required packages/libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %% [markdown]
# ## Load CSV file into pandas dataframe

# %%
url = 'https://raw.githubusercontent.com/NSCC-ITC-Winter2024-DBAS5125-700-MCr/exercise-6-pdushie/main/iowa_house_price_train.csv?token=GHSAT0AAAAAACMTRO2KPW3AA27HXTLHJWDWZNTQAHA'
data = pd.read_csv(url)

# Display first 5 rows of the dataframe
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Display some info about fields in the data and some statistics about the data

# %%
# Display infor about fields and their datatypes
data.info()

# Display some statistical information about the dataset
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ## Profile the data with ydata profiling tool

# %%
# Use YData profiling tool in minimal mode due to large number of columns in dataset
profile_report = ProfileReport(data, minimal = True)
profile_report.to_file("housing_report.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Data Profiling
# 1. Data completeness is 94.1 % for the entire data set as there are 5.9% missing cells
# 2. From the ydata profile report on the datset, the unique field is Id
# 3. For the entire dataset, there are 5.9% missing values. Specific variables such as LotFrontage has 17.7% missing values.

# %%
# Check to see if Id field is unique
data['Id'].is_unique
# Out:
# True

# %% [markdown]
# ## Explore distribution of each feature
# 1. For the LotFrontage feature the distribution shows the presence of outliers as seen from the boxplot.
# 2. TotRmsAbvGrd feature is evenly distributed and has some outliers.

# %%
sns.boxplot(data = data['LotFrontage']).set(title = 'Distribution for Lot Frontage')
# Out:
# [Text(0.5, 1.0, 'Distribution for Lot Frontage')]

# %%
sns.boxplot(data = data['TotRmsAbvGrd']).set(title = 'Distribution for Total Rooms Above Ground')
# Out:
# [Text(0.5, 1.0, 'Distribution for Total Rooms Above Ground')]

# %% [markdown]
# ## Data Visualization

# %%
sns.scatterplot(data=data, x = 'TotalBsmtSF', y = 'SalePrice').set(title='TotalBsmtSF vs SalesPrice')
# Out:
# [Text(0.5, 1.0, 'TotalBsmtSF vs SalesPrice')]

# %%
sns.scatterplot(data=data, x = 'TotalBsmtSF', y = '1stFlrSF').set(title='Total Basment Square Foot vs First Floor Square Foot')
# Out:
# [Text(0.5, 1.0, 'Total Basment Square Foot vs First Floor Square Foot')]

# %%
sns.violinplot(data = data, x='SalePrice')
# Out:
# <Axes: xlabel='SalePrice'>
